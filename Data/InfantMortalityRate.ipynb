# %%
import pandas as pd
import numpy as np

# %%
# The path to our CSV file
file = "InfantMortalityRate_Countries.csv"
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")
# Read our data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    4/24/2019
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4        Afghanistan                          AFG
#
#                                        Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                             NaN             NaN         NaN
# 1                                             NaN             NaN         NaN
# 2                                             NaN             NaN         NaN
# 3                                  Indicator Name  Indicator Code      1960.0
# 4  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN       240.5
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
IMR_df = df.drop(df.index[[0,1,2]])
IMR_df
# Out:
#                         Data Source World Development Indicators  \
# 3                      Country Name                 Country Code
# 4                       Afghanistan                          AFG
# 5                            Angola                          AGO
# 6                           Albania                          ALB
# 7                           Andorra                          AND
# 8              United Arab Emirates                          ARE
# 9                         Argentina                          ARG
# 10                          Armenia                          ARM
# 11              Antigua and Barbuda                          ATG
# 12                        Australia                          AUS
# 13                          Austria                          AUT
# 14                       Azerbaijan                          AZE
# 15                          Burundi                          BDI
# ...

# %%
header = IMR_df.iloc[0]
df = IMR_df.rename(columns = header)
df
# Out:
#                        Country Name  Country Code  \
# 3                      Country Name  Country Code
# 4                       Afghanistan           AFG
# 5                            Angola           AGO
# 6                           Albania           ALB
# 7                           Andorra           AND
# 8              United Arab Emirates           ARE
# 9                         Argentina           ARG
# 10                          Armenia           ARM
# 11              Antigua and Barbuda           ATG
# 12                        Australia           AUS
# 13                          Austria           AUT
# 14                       Azerbaijan           AZE
# 15                          Burundi           BDI
# 16                          Belgium           BEL
# 17                            Benin           BEN
# 18                     Burkina Faso           BFA
# 19                       Bangladesh           BGD
# 20                         Bulgaria           BGR
# ...

# %%
IMR_df = df.drop(df.index[[0]])
IMR_df
# Out:
#                        Country Name Country Code  \
# 4                       Afghanistan          AFG
# 5                            Angola          AGO
# 6                           Albania          ALB
# 7                           Andorra          AND
# 8              United Arab Emirates          ARE
# 9                         Argentina          ARG
# 10                          Armenia          ARM
# 11              Antigua and Barbuda          ATG
# 12                        Australia          AUS
# 13                          Austria          AUT
# 14                       Azerbaijan          AZE
# 15                          Burundi          BDI
# 16                          Belgium          BEL
# 17                            Benin          BEN
# 18                     Burkina Faso          BFA
# 19                       Bangladesh          BGD
# 20                         Bulgaria          BGR
# 21                          Bahrain          BHR
# ...

# %%
# Identify incomplete rows
IMR_df.count()
# Out:
# Country Name      195
# Country Code      195
# Indicator Name    195
# Indicator Code    195
# 1960.0            100
# 1961.0            100
# 1962.0            102
# 1963.0            108
# 1964.0            114
# 1965.0            118
# 1966.0            120
# 1967.0            124
# 1968.0            128
# 1969.0            135
# 1970.0            139
# 1971.0            143
# 1972.0            146
# 1973.0            146
# 1974.0            149
# 1975.0            154
# 1976.0            156
# 1977.0            157
# 1978.0            161
# 1979.0            165
# 1980.0            168
# 1981.0            174
# 1982.0            177
# 1983.0            179
# 1984.0            186
# 1985.0            193
#                  ...
# 1989.0            193
# 1990.0            195
# 1991.0            195
# 1992.0            195
# 1993.0            195
# 1994.0            195
# 1995.0            195
# 1996.0            195
# 1997.0            195
# 1998.0            195
# ...

# %%
IMR_df.replace(np.nan, 0, inplace=True)
IMR_df
# Out:
#                        Country Name Country Code  \
# 4                       Afghanistan          AFG
# 5                            Angola          AGO
# 6                           Albania          ALB
# 7                           Andorra          AND
# 8              United Arab Emirates          ARE
# 9                         Argentina          ARG
# 10                          Armenia          ARM
# 11              Antigua and Barbuda          ATG
# 12                        Australia          AUS
# 13                          Austria          AUT
# 14                       Azerbaijan          AZE
# 15                          Burundi          BDI
# 16                          Belgium          BEL
# 17                            Benin          BEN
# 18                     Burkina Faso          BFA
# 19                       Bangladesh          BGD
# 20                         Bulgaria          BGR
# 21                          Bahrain          BHR
# ...

# %%
IMR_df.to_csv(r'InfantMortalityRate.csv')
