# %%
import pandas as pd

# %%
# The path to our CSV file
file = "health-protection-coverage.csv"

# Read our data into pandas
world_df = pd.read_csv(file)
world_df.head()
# Out:
#                 Entity Code  Year  \
# 0              Albania  ALB  2008
# 1              Algeria  DZA  2005
# 2       American Samoa  ASM  2009
# 3               Angola  AGO  2010
# 4  Antigua and Barbuda  ATG  2007
#
#    Share of population covered by health insurance (ILO (2014)) (%)
# 0                                               23.6
# 1                                               85.2
# 2                                                3.0
# 3                                                0.0
# 4                                               51.1

# %%
# Get a list of all of our columns for easy reference
world_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Share of population covered by health insurance (ILO (2014)) (%)'],
#       dtype='object')

# %%
# Identify incomplete rows
world_df.count()
# Out:
# Entity                                                              162
# Code                                                                162
# Year                                                                162
# Share of population covered by health insurance (ILO (2014)) (%)    162
# dtype: int64

# %%
# The Amount column is the wrong data type. It should be numeric.
world_df.dtypes
# Out:
# Entity                                                               object
# Code                                                                 object
# Year                                                                  int64
# Share of population covered by health insurance (ILO (2014)) (%)    float64
# dtype: object

# %%
world_df
# Out:
#                      Entity Code  Year  \
# 0                   Albania  ALB  2008
# 1                   Algeria  DZA  2005
# 2            American Samoa  ASM  2009
# 3                    Angola  AGO  2010
# 4       Antigua and Barbuda  ATG  2007
# 5                 Argentina  ARG  2009
# 6                   Armenia  ARM  2009
# 7                     Aruba  ABW  2003
# 8                 Australia  AUS  2011
# 9                   Austria  AUT  2010
# 10               Azerbaijan  AZE  2006
# 11                  Bahamas  BHS  1995
# 12                  Bahrain  BHR  2010
# 13               Bangladesh  BGD  2003
# 14                 Barbados  BRB  1995
# 15                  Belarus  BLR  2010
# 16                  Belgium  BEL  2010
# 17                   Belize  BLZ  2009
# 18                    Benin  BEN  2009
# 19                   Bhutan  BTN  2009
# 20                  Bolivia  BOL  2009
# 21   Bosnia and Herzegovina  BIH  2004
# 22                   Brazil  BRA  2009
# ...

# %%
world_df.to_csv(r'healthcare_coverage.csv')
